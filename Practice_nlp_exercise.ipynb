# %%
import pandas as pd

# Specify the file path
file_path = 'test.txt'

# Read the text file with a custom delimiter into a DataFrame
df = pd.read_csv(file_path, delimiter='|')

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#   im feeling rather rotten so im not very ambitious right now;sadness
# 0  im updating my blog because i feel shitty;sadness
# 1  i never make her separate from me because i do...
# 2  i left with my bouquet of red and yellow tulip...
# 3  i was feeling a little vain when i did this on...
# 4  i cant walk into a shop anywhere where i do no...

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Step 1: Read the file and prepare the data
file_path = 'test.txt'

# Read the file into a DataFrame
df = pd.read_csv(file_path, delimiter=';', header=None, names=['text', 'emotion'])

# Display the first few rows
print(df.head())

# Step 2: Create a pipeline for text vectorization and classification
pipeline = Pipeline([
    ('vectorizer', CountVectorizer(ngram_range=(1, 1))),  # Use unigrams
    ('classifier', MultinomialNB())  # Multinomial Naive Bayes classifier
])

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['emotion'], test_size=0.3, random_state=42)

# Fit the pipeline with training data
pipeline.fit(X_train, y_train)

# Get predictions for the test set
y_pred = pipeline.predict(X_test)

# Print the classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
#                                                 text  emotion
# 0  im feeling rather rotten so im not very ambiti...  sadness
# 1          im updating my blog because i feel shitty  sadness
# 2  i never make her separate from me because i do...  sadness
# 3  i left with my bouquet of red and yellow tulip...      joy
# 4    i was feeling a little vain when i did this one  sadness
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.83      0.14      0.24        70
#         fear       0.90      0.14      0.24        64
#          joy       0.56      0.90      0.69       211
#         love       1.00      0.04      0.08        50
#      sadness       0.61      0.79      0.69       184
#     surprise       0.00      0.00      0.00        21
#
#     accuracy                           0.59       600
#    macro avg       0.65      0.34      0.32       600
# weighted avg       0.66      0.59      0.51       600
# ...

# %%
import pandas as pd

# Specify the file path
file_path = 'test.txt'

# Read the file into a DataFrame
df = pd.read_csv(file_path, delimiter=';', header=None, names=['text', 'emotion'])

# Display the first few rows
print(df.head())

# Get the counts of all emotions
emotion_counts = df['emotion'].value_counts()

# Print the counts of all emotions
print("Counts of all emotions:")
print(emotion_counts)
# Out:
#                                                 text  emotion
# 0  im feeling rather rotten so im not very ambiti...  sadness
# 1          im updating my blog because i feel shitty  sadness
# 2  i never make her separate from me because i do...  sadness
# 3  i left with my bouquet of red and yellow tulip...      joy
# 4    i was feeling a little vain when i did this one  sadness
# Counts of all emotions:
# joy         695
# sadness     581
# anger       275
# fear        224
# love        159
# surprise     66
# Name: emotion, dtype: int64

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Step 1: Read the file and prepare the data
file_path = 'test.txt'

# Read the file into a DataFrame
df = pd.read_csv(file_path, delimiter=';', header=None, names=['text', 'emotion'])

# Display the first few rows
print(df.head())

# Step 2: Create a pipeline for text vectorization and classification
pipeline = Pipeline([
    ('vectorizer', CountVectorizer(ngram_range=(1, 1))),  # Use unigrams
    ('classifier', RandomForestClassifier(n_estimators=100, random_state=42))  # Random Forest Classifier
])

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['emotion'], test_size=0.1, random_state=42)
b
# Fit the pipeline with training data
pipeline.fit(X_train, y_train)

# Get predictions for the test set
y_pred = pipeline.predict(X_test)

# Print the classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
#                                                 text  emotion
# 0  im feeling rather rotten so im not very ambiti...  sadness
# 1          im updating my blog because i feel shitty  sadness
# 2  i never make her separate from me because i do...  sadness
# 3  i left with my bouquet of red and yellow tulip...      joy
# 4    i was feeling a little vain when i did this one  sadness
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.82      0.41      0.55        22
#         fear       0.73      0.57      0.64        14
#          joy       0.55      0.96      0.70        69
#         love       0.83      0.26      0.40        19
#      sadness       0.79      0.59      0.67        70
#     surprise       1.00      0.17      0.29         6
#
#     accuracy                           0.65       200
#    macro avg       0.79      0.49      0.54       200
# weighted avg       0.72      0.65      0.63       200

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# Step 1: Read the file and prepare the data
file_path = 'test.txt'

# Read the file into a DataFrame
df = pd.read_csv(file_path, delimiter=';', header=None, names=['text', 'emotion'])

# Display the first few rows
print("Original DataFrame:")
print(df.head())

# Step 2: Create a mapping from emotions to numerical values
emotion_mapping = {emotion: idx for idx, emotion in enumerate(df['emotion'].unique())}
df['emotion_num'] = df['emotion'].map(emotion_mapping)

# Display the DataFrame with numerical emotions
print("DataFrame with Numerical Emotions:")
print(df.head())

# Step 3: Create a pipeline for text vectorization and classification
pipeline = Pipeline([
    ('vectorizer', CountVectorizer(ngram_range=(1, 1))),  # Use unigrams
    ('classifier', RandomForestClassifier(n_estimators=100, random_state=42))  # Random Forest Classifier
])

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['emotion_num'], test_size=0.1, random_state=42)

# Fit the pipeline with training data
pipeline.fit(X_train, y_train)

# Get predictions for the test set
y_pred = pipeline.predict(X_test)

# Print the classification report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=[k for k, v in emotion_mapping.items()]))

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=df['emotion_num'].unique())

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[k for k, v in emotion_mapping.items()], yticklabels=[k for k, v in emotion_mapping.items()])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix Heatmap')
plt.show()
# Out:
# Original DataFrame:
#                                                 text  emotion
# 0  im feeling rather rotten so im not very ambiti...  sadness
# 1          im updating my blog because i feel shitty  sadness
# 2  i never make her separate from me because i do...  sadness
# 3  i left with my bouquet of red and yellow tulip...      joy
# 4    i was feeling a little vain when i did this one  sadness
# DataFrame with Numerical Emotions:
#                                                 text  emotion  emotion_num
# 0  im feeling rather rotten so im not very ambiti...  sadness            0
# 1          im updating my blog because i feel shitty  sadness            0
# 2  i never make her separate from me because i do...  sadness            0
# 3  i left with my bouquet of red and yellow tulip...      joy            1
# 4    i was feeling a little vain when i did this one  sadness            0
# Classification Report:
#               precision    recall  f1-score   support
#
# ...

# %%
import spacy

# load english language model and create nlp object from it
nlp = spacy.load("en_core_web_sm") 


#use this utility function to get the preprocessed text data
def preprocess(text):
    # remove stop words and lemmatize the text
    doc = nlp(text)
    filtered_tokens = []
    for token in doc:
        if token.is_stop or token.is_punct:
            continue
        filtered_tokens.append(token.lemma_)
    
    return " ".join(filtered_tokens)

# %%
# create a new column "preprocessed_comment" and use the utility function above to get the clean data
# this will take some time, please be patient
df['preprocessed_comment'] = df['text'].apply(preprocess)

# %%
#Do the 'train-test' splitting with test size of 20% with random state of 2022 and stratify sampling too
#Note: Use the preprocessed_Comment
X_train, X_test, y_train, y_test = train_test_split(
    df.preprocessed_comment, 
    df.emotion_num, 
    test_size=0.2, # 20% samples will go to test dataset
    random_state=2022,
    stratify=df.emotion_num
)

# %%
print("Shape of X_train: ", X_train.shape)
print("Shape of X_test: ", X_test.shape)
# Out:
# Shape of X_train:  (1600,)
# Shape of X_test:  (400,)

# %%
# Step 3: Create a pipeline for text vectorization and classification
pipeline = Pipeline([
    ('vectorizer', CountVectorizer(ngram_range=(1, 1))),  # Use unigrams
    ('classifier', RandomForestClassifier(n_estimators=100, random_state=42))  # Random Forest Classifier
])

# Fit the pipeline with training data
pipeline.fit(X_train, y_train)

# Get predictions for the test set
y_pred = pipeline.predict(X_test)

# Print the classification report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=[k for k, v in emotion_mapping.items()]))

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=df['emotion_num'].unique())

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[k for k, v in emotion_mapping.items()], yticklabels=[k for k, v in emotion_mapping.items()])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix Heatmap')
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      sadness       0.68      0.89      0.77       116
#          joy       0.75      0.74      0.75       139
#         fear       0.89      0.71      0.79        45
#        anger       0.84      0.69      0.76        55
#         love       0.75      0.38      0.50        32
#     surprise       0.47      0.54      0.50        13
#
#     accuracy                           0.74       400
#    macro avg       0.73      0.66      0.68       400
# weighted avg       0.75      0.74      0.73       400

# %%
# Step 2: Create a pipeline for text vectorization and classification with MultinomialNB
pipeline = Pipeline([
    ('vectorizer', CountVectorizer(ngram_range=(1, 1))),  # Use unigrams
    ('classifier', MultinomialNB())  # Multinomial Naive Bayes Classifier
])

# Fit the pipeline with training data
pipeline.fit(X_train, y_train)

# Get predictions for the test set
y_pred = pipeline.predict(X_test)

# Print the classification report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=[k for k, v in emotion_mapping.items()]))

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=df['emotion_num'].unique())

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[k for k, v in emotion_mapping.items()], yticklabels=[k for k, v in emotion_mapping.items()])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix Heatmap for MultinomialNB')
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      sadness       0.56      0.77      0.64       116
#          joy       0.62      0.88      0.73       139
#         fear       0.59      0.22      0.32        45
#        anger       0.70      0.25      0.37        55
#         love       0.75      0.09      0.17        32
#     surprise       0.00      0.00      0.00        13
#
#     accuracy                           0.60       400
#    macro avg       0.54      0.37      0.37       400
# weighted avg       0.60      0.60      0.54       400
# E:\anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
# Step 2: Create a pipeline for text vectorization and classification with KNeighborsClassifier
pipeline = Pipeline([
    ('vectorizer', CountVectorizer(ngram_range=(1, 1))),  # Use unigrams
    ('classifier', KNeighborsClassifier())  # KNeighbors Classifier
])

# Fit the pipeline with training data
pipeline.fit(X_train, y_train)

# Get predictions for the test set
y_pred = pipeline.predict(X_test)

# Print the classification report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=[k for k, v in emotion_mapping.items()]))

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=df['emotion_num'].unique())

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[k for k, v in emotion_mapping.items()], yticklabels=[k for k, v in emotion_mapping.items()])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix Heatmap for MultinomialNB')
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      sadness       0.31      0.90      0.46       116
#          joy       0.63      0.19      0.29       139
#         fear       0.50      0.09      0.15        45
#        anger       0.17      0.04      0.06        55
#         love       0.00      0.00      0.00        32
#     surprise       0.00      0.00      0.00        13
#
#     accuracy                           0.34       400
#    macro avg       0.27      0.20      0.16       400
# weighted avg       0.39      0.34      0.26       400
